# %% [markdown]
# ## Inference

# %%
import os
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F
from torch import optim
import numpy as np
from collections import OrderedDict
import time
import random

model_filename = "tridonn"

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

N0 = 527
N1 = 20
N2 = 1
NX = 1

model = nn.Sequential(OrderedDict([
    ('dense1', nn.Linear(N0, N1)),
    ('act1', nn.ReLU()),
    ('dense2', nn.Linear(N1, N2)),
    #('act2', nn.ReLU()),
    #('output', nn.Linear(N2, NX)),
    ('outact', nn.Sigmoid()),
]))

model.load_state_dict(torch.load(model_filename))
model.eval()

def rate_file(filename):
    rate_file = open(filename, "r").readlines()
    rate_lines = [l.replace('\n', '').split('\t') for l in rate_file]

    my_test_x = [[float(i) for i in l[1:]] for l in rate_lines[1:]]
    song_names = [l[0] for l in rate_lines[1:]]
    
    print("Song ratings: [0-1]")
    
    results = {}
    
    for i in range(len(my_test_x)):
        X = torch.tensor(my_test_x[i])
        song_name = song_names[i].split('/')[-1]
        logits = model(X)
        results[song_name] = float(logits[0])
    return results
# Out:
# Using cpu device

# %%
values = rate_file("my_fun_playlist.csv")
dict(sorted(values.items(), key=lambda x: -x[1]))
# Out:
# Song ratings: [0-1]
# {'85108589 - Digitalism - Zdar C1u6 - Holograms.m4a.wav': 0.11063352227210999,
#  '74886176 - Portugal. The Man - Woodstock - Tidal Wave.m4a.wav': 0.11053586006164551,
#  '55130775 - The Beatles - Magical Mystery Tour (Remastered) - Strawberry Fields Forever (Remastered 2009).m4a.wav': 0.1090255007147789,
#  '51487647 - Deluxe - Stachelight - Shoes.m4a.wav': 0.10856501758098602,
#  '91642505 - Tame Impala - Currents - Let It Happen.m4a.wav': 0.10850847512483597,
#  '198746918 - Die Antwoord - Donker Mag - Strunk.m4a.wav': 0.10833524912595749,
#  '49990992 - Glass Animals - ZABA (Deluxe) - Gooey.m4a.wav': 0.10804326832294464,
#  '226480299 - Flume - TheSoundYouNeed, Vol. 1 - Drop The Game.m4a.wav': 0.1080157682299614,
#  '30209249 - Glass Animals - ZABA - Toes.m4a.wav': 0.1077541932463646,
#  '54329308 - Miike Snow - Genghis Khan - Genghis Khan.m4a.wav': 0.1070159301161766,
#  '106894980 - Tame Impala - Indie Hits - The Less I Know The Better.m4a.wav': 0.10642515867948532,
#  '74447704 - alt-J - RELAXER - Deadcrush.m4a.wav': 0.10620468109846115,
#  '20331019 - Portugal. The Man - Evil Friends - Smile.m4a.wav': 0.10598912835121155,
#  '82440278 - Flume - Flume- Deluxe Edition - Insane (L D R U Remix).m4a.wav': 0.10578488558530807,
#  '34395402 - alt-J - An Awesome Wave - Tessellate.m4a.wav': 0.10554199665784836,
#  '3670232 - Passion Pit - Manners - Sleepyhead.m4a.wav': 0.10530086606740952,
#  '35410166 - Galantis - Runaway (U & I) - Runaway (U & I).m4a.wav': 0.10509677231311798,
#  '58085927 - Spoon - Gimme Fiction (Deluxe Edition) - I Turn My Camera On.m4a.wav': 0.10495086014270782,
#  '1404367 - Gorillaz - Demon Days - DARE.m4a.wav': 0.10421466082334518,
#  '64145298 - Glass Animals - How To Be A Human Being - Poplar St.m4a.wav': 0.10380621999502182,
